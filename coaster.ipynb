# %% [markdown]
# **INTRODUCTORY TO EXPLANATORY DATA ANALYSIS**

# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df = pd.read_csv('coaster_db.csv')

# %%
df = df[['coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced', 'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph', 'height_ft', 'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.loc[(df["Status"] == "Removed") & (df["year_introduced"] == 1901)]
# Out:
#                    coaster_name Location   Status    Manufacturer  \
# 3  Loop the Loop (Coney Island)    Other  Removed  Edwin Prescott
# 4  Loop the Loop (Young's Pier)    Other  Removed  Edwin Prescott
#
#    year_introduced  latitude  longitude Type_Main opening_date_clean  \
# 3             1901   40.5745   -73.9780     Steel         1901-01-01
# 4             1901   39.3538   -74.4342     Steel         1901-01-01
#
#    speed_mph  height_ft  Inversions_clean  Gforce_clean
# 3        NaN        NaN                 1           NaN
# 4        NaN        NaN                 1           NaN

# %%
df = df.rename(columns={'coaster_name': 'Coaster_Name', 'year_introduced': 'Year_Introduced', 'opening_date_clean': 'Opening_Date', 'speed_mph': 'Speed_mph', 'height_ft': 'Height_ft', 'Inversions_clean': 'Inversion', 'Gforce_clean': 'Gforce'})

# %%
df.isna().sum()
# Out:
# Coaster_Name         0
# Location             0
# Status             213
# Manufacturer        59
# Year_Introduced      0
# latitude           275
# longitude          275
# Type_Main            0
# Opening_Date       250
# Speed_mph          150
# Height_ft          916
# Inversion            0
# Gforce             725
# dtype: int64

# %%
df.query('Coaster_Name == "Derby Racer"')
# Out:
#    Coaster_Name      Location   Status    Manufacturer  Year_Introduced  \
# 14  Derby Racer  Revere Beach  Removed  Fred W. Pearce             1911
# 60  Derby Racer  Revere Beach  Removed  Fred W. Pearce             1937
#
#     latitude  longitude Type_Main Opening_Date  Speed_mph  Height_ft  \
# 14     42.42    -70.986      Wood   1911-01-01        NaN        NaN
# 60     42.42    -70.986      Wood   1911-01-01        NaN        NaN
#
#     Inversion  Gforce
# 14          0     NaN
# 60          0     NaN

# %%
df = df[~df.duplicated(subset=['Coaster_Name', 'Location', 'Opening_Date'])].reset_index(drop=True).copy()

# %% [markdown]
# **FEATURE UNDERSTANDING**
